# %% [markdown]
# # Chest X-Ray Pneumonia Detection using Deep Learning
#
# This notebook demonstrates the process of building a deep learning model to detect pneumonia from chest X-ray images. It covers data loading, preprocessing, model training, and evaluation using Convolutional Neural Networks (CNNs).

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Import data_preprocessing utility
# Adjust this to point to your project's root directory
sys.path.append(os.path.abspath('../'))

from src.utils.data_preprocessing import create_image_data_generators

# --- 1. Data Setup ---
# Ensure you have downloaded the Chest X-Ray Images (Pneumonia) dataset from Kaggle
# Download from: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# Organize it in the following structure:
# data/chest_xray_pneumonia/
# ├── train/
# │   ├── NORMAL/
# │   └── PNEUMONIA/
# └── val/
#     ├── NORMAL/
#     └── PNEUMONIA/

train_dir = "../data/chest_xray_pneumonia/train"
val_dir = "../data/chest_xray_pneumonia/val"

# Image parameters
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 32
EPOCHS = 15

print(f"Training directory: {train_dir}")
print(f"Validation directory: {val_dir}")

# Check if directories exist
if not os.path.exists(train_dir):
    print(f"Warning: Training directory {train_dir} not found.")
    print("Creating dummy directory structure for demonstration.")
    os.makedirs(f"{train_dir}/NORMAL", exist_ok=True)
    os.makedirs(f"{train_dir}/PNEUMONIA", exist_ok=True)
    os.makedirs(f"{val_dir}/NORMAL", exist_ok=True)
    os.makedirs(f"{val_dir}/PNEUMONIA", exist_ok=True)
    
    # Create dummy image files
    import numpy as np
    from PIL import Image
    
    for i in range(5):
        dummy_img = Image.fromarray(np.random.randint(0, 255, (150, 150, 3), dtype=np.uint8))
        dummy_img.save(f"{train_dir}/NORMAL/dummy_{i}.jpg")
        dummy_img.save(f"{train_dir}/PNEUMONIA/dummy_{i}.jpg")
        dummy_img.save(f"{val_dir}/NORMAL/dummy_{i}.jpg")
        dummy_img.save(f"{val_dir}/PNEUMONIA/dummy_{i}.jpg")
    
    print("Dummy data created for demonstration.")

# --- 2. Data Loading and Preprocessing ---
train_generator, val_generator = create_image_data_generators(
    train_dir, val_dir, IMG_HEIGHT, IMG_WIDTH, BATCH_SIZE
)

if train_generator and val_generator:
    print(f"Found {train_generator.samples} training images belonging to {train_generator.num_classes} classes.")
    print(f"Found {val_generator.samples} validation images belonging to {val_generator.num_classes} classes.")
    print(f"Class indices: {train_generator.class_indices}")
else:
    print("Error: Could not create data generators. Please check your data directory structure.")

# Visualize some sample images
def plot_sample_images(generator, num_images=8):
    fig, axes = plt.subplots(2, 4, figsize=(12, 6))
    axes = axes.ravel()
    
    # Get a batch of images and labels
    images, labels = next(generator)
    
    for i in range(min(num_images, len(images))):
        axes[i].imshow(images[i])
        axes[i].set_title(f"Label: {"PNEUMONIA" if labels[i] == 1 else "NORMAL"}")
        axes[i].axis("off")
    
    plt.tight_layout()
    plt.show()

if train_generator:
    plot_sample_images(train_generator)

# --- 3. Model Building ---
# Option 1: Simple CNN
def create_simple_cnn():
    model = Sequential([
        Conv2D(32, (3, 3), activation="relu", input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation="relu"),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation="relu"),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation="relu"),
        MaxPooling2D(2, 2),
        Flatten(),
        Dropout(0.5),
        Dense(512, activation="relu"),
        Dense(1, activation="sigmoid")
    ])
    return model

# Option 2: Transfer Learning with VGG16
def create_vgg16_model():
    base_model = VGG16(weights="imagenet", include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    base_model.trainable = False  # Freeze the base model
    
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation="relu"),
        Dropout(0.5),
        Dense(1, activation="sigmoid")
    ])
    return model

# Choose model type
MODEL_TYPE = "vgg16"  # Change to "simple" for simple CNN

if MODEL_TYPE == "simple":
    model = create_simple_cnn()
    print("Created Simple CNN model")
else:
    model = create_vgg16_model()
    print("Created VGG16 Transfer Learning model")

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# --- 4. Model Training ---
if train_generator and val_generator:
    print("Starting model training...")
    
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_generator,
        validation_steps=val_generator.samples // BATCH_SIZE,
        verbose=1
    )
    
    print("Model training complete.")
    
    # Plot training history
    def plot_training_history(history):
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
        
        # Plot accuracy
        ax1.plot(history.history["accuracy"], label="Training Accuracy")
        ax1.plot(history.history["val_accuracy"], label="Validation Accuracy")
        ax1.set_title("Model Accuracy")
        ax1.set_xlabel("Epoch")
        ax1.set_ylabel("Accuracy")
        ax1.legend()
        ax1.grid(True)
        
        # Plot loss
        ax2.plot(history.history["loss"], label="Training Loss")
        ax2.plot(history.history["val_loss"], label="Validation Loss")
        ax2.set_title("Model Loss")
        ax2.set_xlabel("Epoch")
        ax2.set_ylabel("Loss")
        ax2.legend()
        ax2.grid(True)
        
        plt.tight_layout()
        plt.show()
    
    plot_training_history(history)
    
    # --- 5. Model Evaluation ---
    print("Evaluating model...")
    
    # Evaluate on validation set
    loss, accuracy = model.evaluate(val_generator, verbose=0)
    print(f"Validation Loss: {loss:.4f}")
    print(f"Validation Accuracy: {accuracy:.4f}")
    
    # Get predictions
    val_generator.reset()
    predictions = model.predict(val_generator, verbose=0)
    predicted_classes = (predictions > 0.5).astype(int).flatten()
    
    # Get true labels
    true_classes = val_generator.classes
    
    # Classification report
    print("\nClassification Report:")
    print(classification_report(true_classes, predicted_classes, 
                              target_names=list(val_generator.class_indices.keys())))
    
    # Confusion matrix
    cm = confusion_matrix(true_classes, predicted_classes)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
                xticklabels=list(val_generator.class_indices.keys()),
                yticklabels=list(val_generator.class_indices.keys()))
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
    
    # ROC Curve
    fpr, tpr, _ = roc_curve(true_classes, predictions.flatten())
    roc_auc = auc(fpr, tpr)
    
    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, color="darkorange", lw=2, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("Receiver Operating Characteristic (ROC) Curve")
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()
    
    print(f"ROC-AUC: {roc_auc:.4f}")
    
    # --- 6. Save Model ---
    model.save("pneumonia_detection_model.h5")
    print("Model saved as 'pneumonia_detection_model.h5'")
    
else:
    print("Cannot proceed with training due to data loading issues.")

# --- 7. Prediction Function ---
def predict_pneumonia(image_path, model, img_height=150, img_width=150):
    """
    Predicts whether a chest X-ray shows pneumonia or not.
    
    Args:
        image_path (str): Path to the chest X-ray image
        model: Trained model
        img_height (int): Height to resize image to
        img_width (int): Width to resize image to
    
    Returns:
        tuple: (prediction_label, confidence_score)
    """
    img = tf.keras.utils.load_img(image_path, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    img_array = img_array / 255.0  # Normalize
    
    prediction = model.predict(img_array)[0][0]
    
    if prediction > 0.5:
        return "PNEUMONIA", prediction
    else:
        return "NORMAL", 1 - prediction

# Example usage (uncomment to test with a real image):
# result, confidence = predict_pneumonia("/path/to/your/chest_xray.jpg", model)
# print(f"Prediction: {result} (Confidence: {confidence:.4f})")
# Out:
# Training directory: ../data/chest_xray_pneumonia/train
# Validation directory: ../data/chest_xray_pneumonia/val
# Setting up image data generators...
# Found 10 images belonging to 2 classes.
# Found 10 images belonging to 2 classes.
# Image data generators created.
# Found 10 training images belonging to 2 classes.
# Found 10 validation images belonging to 2 classes.
# Class indices: {'NORMAL': 0, 'PNEUMONIA': 1}
# 2025-07-25 04:16:00.945742: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Created VGG16 Transfer Learning model
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ...
